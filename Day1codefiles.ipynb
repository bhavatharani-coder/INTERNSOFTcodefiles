# %%
print("hello")
# Out:
# hello

# %%
for i in range(1,6):
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
for i in range(1,6):
    for j in range(0,i):
        print("*",end=" ")
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
